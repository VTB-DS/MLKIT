# %% [markdown]
# # Демонстрация финализации и калибровки модели

# %%
# расширяем поле, убираем предупреждения
from IPython.core.display import display, HTML
display(HTML('<style>.container {width:95% !important;}</style>'))

import warnings
warnings.filterwarnings('ignore')

# Стандартные библиотеки для анализа
import pandas as pd
pd.options.display.float_format = '{:20,.2f}'.format
# Out:
# <style>.container {width:95% !important;}</style>

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold

# %%
import sys
sys.path.append('../')

# Наша разработанная библиотека
from autobinary import AutoTrees, base_pipe, FinalModel, BalanceCover

# %%
import sklearn as sk
import catboost as ctb
import matplotlib as mplot
import autobinary as ab
import numpy as np
import scipy as sc

print('pandas: ', pd.__version__)
print('numpy: ', np.__version__)
print('scipy: ', sc.__version__)
print('sklearn: ', sk.__version__)
print('catboost: ', ctb.__version__)
print('matplotlib: ', mplot.__version__)
print('autobinary: ', ab.__version__)
# Out:
# pandas:  1.3.4
# numpy:  1.22.2
# scipy:  1.7.3
# sklearn:  1.1.3
# catboost:  1.0.4
# matplotlib:  3.7.0
# autobinary:  1.0.9

# %%
sample = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

print('Размерность данных:', sample.shape)
sample.head(2)
# Out:
# Размерность данных: (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
#
#                    Age  SibSp  Parch     Ticket                 Fare Cabin  \
# 0                22.00      1      0  A/5 21171                 7.25   NaN
# 1                38.00      1      0   PC 17599                71.28   C85
#
#   Embarked
# 0        S
# 1        C

# %%
num_columns = [
    'Age', 'Fare'
]

cat_columns = [
    'Pclass', 'Sex', 'Embarked', 'SibSp', 'Parch'
]

target = ['Survived']

# %%
X_train, X_val, y_train, y_val = train_test_split(
    sample,
    sample[target],
    test_size=0.3,
    stratify=sample[target],
    random_state=42
)

# %%
params = {
    'learning_rate':0.01,
    'iterations':1000,
    'subsample':0.9,
    'colsample_bylevel':0.9,
    'depth':6,
    'loss_function':'Logloss',
    'thread_count':-1,
    'random_state':42,
    'eval_metric':'AUC',
    'verbose':250}

# %% [markdown]
# ## Обучение и калибровка по двум сценариям:
# 1) Если нам нужно и обучить и откалиброваться передаем на вход класса:
#     * base_pipe - пайплайн обработки
#     * num_columns / cat_columns - количественные и категориальные переменные
#     * model_type - тип алгоритма
#     * model_params - параметры алгоритма
#     * task_type - тип задачи
#
# 2) Если у нас есть модель и нам нужно только откалиброваться:
#     * prep_pipe_final - обученный пайплайн обработки
#     * model_final - обученный алгоритм
#     * num_columns / cat_columns - количественные и категориальные переменные
#     * task_type - тип задачи

# %% [markdown]
# #### Сценарий №1

# %%
# Инициализация класса соло модели

final_model = FinalModel(
    prep_pipe_final=None,
    model_final=None,

    base_pipe=base_pipe,
    num_columns=num_columns,
    cat_columns=cat_columns,

    model_type='catboost',
    model_params=params,
    task_type='classification')

# %%
# Обучение финальной соло модели

final_model.fit(X_train,y_train)
# Out:
# Определены количественные и категориальные переменные!
# 0:	total: 54.6ms	remaining: 54.6s
# 250:	total: 221ms	remaining: 658ms
# 500:	total: 355ms	remaining: 354ms
# 750:	total: 486ms	remaining: 161ms
# 999:	total: 609ms	remaining: 0us
# 'Пайплайн и модель обучены!'

# %% [markdown]
# #### Сценарий №2

# %%
# Подгружаем трансформер факторов и модель

prep_pipe = base_pipe(
    num_columns=num_columns, 
    cat_columns=cat_columns)

prep_pipe.fit(X_train,y_train)

catb_model = ctb.CatBoostClassifier(**params)
catb_model.fit(prep_pipe.transform(X_train),y_train)
# Out:
# Определены количественные и категориальные переменные!
# 0:	total: 365us	remaining: 365ms
# 250:	total: 124ms	remaining: 369ms
# 500:	total: 246ms	remaining: 245ms
# 750:	total: 373ms	remaining: 124ms
# 999:	total: 503ms	remaining: 0us

# %%
# Инициализация класса соло модели

final_model = FinalModel(
    prep_pipe_final=prep_pipe,
    model_final=catb_model,

    base_pipe=None,
    num_columns=num_columns,
    cat_columns=cat_columns,

    model_type=None,
    model_params=None,
    task_type='classification')

# %%
# Проверка обучения финальной соло модели

final_model.fit(X_train,y_train)
# Out:
# Модель обучена! Доступны только метрики и калибровка!

# %% [markdown]
# ### Отрисовка метрики баланса классов и получение скоров

# %%
# Если хотим проскорить одну из выборок

train_scores = final_model.predict(X_train)
val_scores = final_model.predict(X_val)

# %%
# Метрика отношение балансов для трейна

tr_table_cover_1 = final_model.balance_cover_1(X_train, y_train, step=30, end=650)
tr_table_cover_1
# Out:
# Всего записей в выборке:  623
# Всего таргетов в выборке:  239
#     start_bucket  end_bucket  turget_in_bucket       bucket_bal (%)  \
# 0              0          30                30               100.00
# 1              0          60                60               100.00
# 2              0          90                90               100.00
# 3              0         120               120               100.00
# 4              0         150               148                98.67
# 5              0         180               175                97.22
# 6              0         210               197                93.81
# 7              0         240               210                87.50
# 8              0         270               217                80.37
# 9              0         300               226                75.33
# 10             0         330               230                69.70
# 11             0         360               232                64.44
# 12             0         390               235                60.26
# 13             0         420               237                56.43
# 14             0         450               237                52.67
# 15             0         480               237                49.38
# 16             0         510               238                46.67
# 17             0         540               239                44.26
# 18             0         570               239                41.93
# 19             0         600               239                39.83
# 20             0         630               239                37.94
# 21             0         660               239                36.21
#
#            coverage (%)         base_bal (%)  bucket_bal/base_bal  \
# 0                 12.55                38.36                 2.61
# 1                 25.10                38.36                 2.61
# 2                 37.66                38.36                 2.61
# 3                 50.21                38.36                 2.61
# 4                 61.92                38.36                 2.57
# 5                 73.22                38.36                 2.53
# 6                 82.43                38.36                 2.45
# 7                 87.87                38.36                 2.28
# 8                 90.79                38.36                 2.10
# 9                 94.56                38.36                 1.96
# 10                96.23                38.36                 1.82
# 11                97.07                38.36                 1.68
# 12                98.33                38.36                 1.57
# 13                99.16                38.36                 1.47
# 14                99.16                38.36                 1.37
# 15                99.16                38.36                 1.29
# 16                99.58                38.36                 1.22
# 17               100.00                38.36                 1.15
# 18               100.00                38.36                 1.09
# 19               100.00                38.36                 1.04
# 20               100.00                38.36                 0.99
# 21               100.00                38.36                 0.94
#
#                     auc
# 0                100.00
# 1                100.00
# 2                100.00
# 3                100.00
# 4                 84.97
# 5                 85.09
# 6                 87.68
# 7                 90.90
# 8                 92.64
# 9                 91.31
# 10                92.27
# 11                93.24
# 12                93.36
# 13                93.64
# 14                94.54
# 15                95.21
# 16                95.36
# 17                95.43
# 18                95.84
# 19                96.19
# 20                96.42
# 21                96.42

# %%
# Метрика отношение балансов для валидации

te_table_cover_1 = final_model.balance_cover_1(X_val, y_val, step=15, end=250)
te_table_cover_1
# Out:
# Всего записей в выборке:  268
# Всего таргетов в выборке:  103
#     start_bucket  end_bucket  turget_in_bucket       bucket_bal (%)  \
# 0              0          15                15               100.00
# 1              0          30                30               100.00
# 2              0          45                42                93.33
# 3              0          60                54                90.00
# 4              0          75                66                88.00
# 5              0          90                71                78.89
# 6              0         105                78                74.29
# 7              0         120                84                70.00
# 8              0         135                86                63.70
# 9              0         150                89                59.33
# 10             0         165                92                55.76
# 11             0         180                95                52.78
# 12             0         195                97                49.74
# 13             0         210                98                46.67
# 14             0         225                98                43.56
# 15             0         240                99                41.25
# 16             0         255               100                39.22
#
#            coverage (%)         base_bal (%)  bucket_bal/base_bal  \
# 0                 14.56                38.43                 2.60
# 1                 29.13                38.43                 2.60
# 2                 40.78                38.43                 2.43
# 3                 52.43                38.43                 2.34
# 4                 64.08                38.43                 2.29
# 5                 68.93                38.43                 2.05
# 6                 75.73                38.43                 1.93
# 7                 81.55                38.43                 1.82
# 8                 83.50                38.43                 1.66
# 9                 86.41                38.43                 1.54
# 10                89.32                38.43                 1.45
# 11                92.23                38.43                 1.37
# 12                94.17                38.43                 1.29
# 13                95.15                38.43                 1.21
# 14                95.15                38.43                 1.13
# 15                96.12                38.43                 1.07
# 16                97.09                38.43                 1.02
#
#                     auc
# 0                100.00
# 1                100.00
# 2                 76.98
# 3                 75.93
# 4                 72.05
# 5                 82.32
# 6                 81.41
# 7                 80.51
# 8                 84.16
# 9                 84.63
# 10                84.69
# 11                84.41
# 12                84.92
# 13                86.01
# 14                87.66
# 15                88.03
# 16                88.27

# %% [markdown]
# #### Процентность таргета в бакетах

# %%
# Метрика процента таргета для трейна

tr_table_cover_2 = final_model.balance_cover_2(X_train, y_train, step=30, end=300)
tr_table_cover_2
# Out:
# Всего записей в выборке:  623
# Всего таргетов в выборке:  239
#    start_bucket  end_bucket  target_in_bucket       bucket_bal (%)  \
# 0             0          30                30               100.00
# 1            30          60                30               100.00
# 2            60          90                30               100.00
# 3            90         120                30               100.00
# 4           120         150                28                93.33
# 5           150         180                27                90.00
# 6           180         210                22                73.33
# 7           210         240                13                43.33
# 8           240         270                 7                23.33
# 9           270         300                 9                30.00
#
#           coverage (%)         base_bal (%)  bucket_bal/base_bal  \
# 0                12.55                38.36                 2.61
# 1                12.55                38.36                 2.61
# 2                12.55                38.36                 2.61
# 3                12.55                38.36                 2.61
# 4                11.72                38.36                 2.43
# 5                11.30                38.36                 2.35
# 6                 9.21                38.36                 1.91
# 7                 5.44                38.36                 1.13
# 8                 2.93                38.36                 0.61
# 9                 3.77                38.36                 0.78
#
#                    auc
# 0               100.00
# 1               100.00
# 2               100.00
# 3               100.00
# 4                20.54
# 5                60.49
# 6                57.39
# 7                59.95
# 8                60.25
# 9                31.48

# %%
# Метрика процента таргета для валидации

te_table_cover_2 = final_model.balance_cover_2(X_val, y_val, step=15, end=250)
te_table_cover_2
# Out:
# Всего записей в выборке:  268
# Всего таргетов в выборке:  103
#     start_bucket  end_bucket  target_in_bucket       bucket_bal (%)  \
# 0              0          15                15               100.00
# 1             15          30                15               100.00
# 2             30          45                12                80.00
# 3             45          60                12                80.00
# 4             60          75                12                80.00
# 5             75          90                 5                33.33
# 6             90         105                 7                46.67
# 7            105         120                 6                40.00
# 8            120         135                 2                13.33
# 9            135         150                 3                20.00
# 10           150         165                 3                20.00
# 11           165         180                 3                20.00
# 12           180         195                 2                13.33
# 13           195         210                 1                 6.67
# 14           210         225                 0                 0.00
# 15           225         240                 1                 6.67
# 16           240         255                 1                 6.67
#
#            coverage (%)         base_bal (%)  bucket_bal/base_bal  \
# 0                 14.56                38.43                 2.60
# 1                 14.56                38.43                 2.60
# 2                 11.65                38.43                 2.08
# 3                 11.65                38.43                 2.08
# 4                 11.65                38.43                 2.08
# 5                  4.85                38.43                 0.87
# 6                  6.80                38.43                 1.21
# 7                  5.83                38.43                 1.04
# 8                  1.94                38.43                 0.35
# 9                  2.91                38.43                 0.52
# 10                 2.91                38.43                 0.52
# 11                 2.91                38.43                 0.52
# 12                 1.94                38.43                 0.35
# 13                 0.97                38.43                 0.17
# 14                 0.00                38.43                 0.00
# 15                 0.97                38.43                 0.17
# 16                 0.97                38.43                 0.17
#
#                     auc
# 0                100.00
# 1                100.00
# 2                 19.44
# 3                 63.89
# 4                 55.56
# 5                 45.00
# 6                 64.29
# 7                 33.33
# 8                 76.92
# 9                 44.44
# 10                69.44
# 11                69.44
# 12                80.77
# 13                71.43
# 14               100.00
# 15                35.71
# 16                57.14

# %% [markdown]
# ## Этап калибровки

# %%
# Калибровка на валидации

final_model.calibration(X_val, y_val, n_bins=10)

# %% [markdown]
# ### Формирование базового скора, сигмоидной калибровки и изотонической

# %%
# Выбор калибровки и сравнение с базовым скором

scores = final_model.calibration_compare(X_val, y_val, calib_compare='scores_iso')
scores
# Out:
#              scores_base          scores_sigm           scores_iso  target
# 0                   0.99                 0.92                 1.00       1
# 1                   0.99                 0.92                 1.00       1
# 2                   0.99                 0.92                 1.00       1
# 3                   0.99                 0.92                 1.00       1
# 4                   0.99                 0.92                 1.00       1
# ..                   ...                  ...                  ...     ...
# 263                 0.02                 0.08                 0.08       1
# 264                 0.02                 0.08                 0.00       0
# 265                 0.01                 0.08                 0.00       0
# 266                 0.01                 0.08                 0.00       0
# 267                 0.01                 0.08                 0.00       0
#
# [268 rows x 4 columns]

# %% [markdown]
# ## Сохранение пиклов
# Указываем что сохраняем и название папки для создания
#
# * columns - сохранение количественных и категориальных переменных
# * prep_pipe - сохранение пайплайна трансформации переменных
# * model - сохранение модели
# * calibration - сохранение калибровки
# * type_calibration - тип сохраняемой калибровки
# * path - название генерируемой директории

# %%
final_model.get_pickles(
    columns=True,
    prep_pipe=True,
    model=True,
    calibration=True,
    type_calibration='iso',
    path='final_results')
# Out:
# 'Все атрибуты сохранены!'
